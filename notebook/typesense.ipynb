# %% [markdown]
# RAG application using Typesense and Groq AI

# %%
from dotenv import load_dotenv
import os
import pandas as pd
import typesense
import json

# %%
data_csv = pd.read_csv("../data/football_data/ginf.csv",encoding='UTF-8')
data_csv.drop(columns = ['odd_over','odd_under','odd_bts','odd_bts_n'], axis=1, inplace=True)
data_csv.to_json("../data/football_data/football_data.json", orient="records")

# %%
data_dict = data_csv.to_dict(orient="records")
data_dict[0]
# Out:
# {'id_odsp': 'UFot0hit/',
#  'link_odsp': '/soccer/germany/bundesliga-2011-2012/dortmund-hamburger-UFot0hit/',
#  'adv_stats': True,
#  'date': '2011-08-05',
#  'league': 'D1',
#  'season': 2012,
#  'country': 'germany',
#  'ht': 'Borussia Dortmund',
#  'at': 'Hamburg SV',
#  'fthg': 3,
#  'ftag': 1,
#  'odd_h': 1.56,
#  'odd_d': 4.41,
#  'odd_a': 7.42}

# %%
load_dotenv()

client = typesense.Client({
    'nodes': [{
        'host': os.getenv("TYPESENSE_HOST"),
        'port': '443',
        'protocol': 'https'
    }],
    'api_key': os.getenv("TYPESENSE_API_KEY"),
    'connection_timeout_seconds': 2
})
# Out:
# Deprecation warning: AnalyticsRulesV1 is deprecated on v30+. Use client.analytics instead.

# %%
# book schema is used to create schema for the document collection

book_sachema = {
    'name': 'football_articles',
    'fields': [
        {'name': 'id_odsp', 'type': 'string'},
        {'name': 'link_odsp', 'type': 'string'},
        {'name': 'adv_stats', 'type': 'bool', 'facet': True},
        {'name': 'date', 'type': 'string'},
        {'name': 'league', 'type': 'string'},
        {'name': 'season', 'type': 'int32'},
        {'name': 'country', 'type': 'string'},
        {'name': 'ht', 'type': 'string'},
        {'name': 'at', 'type': 'string'},
        {'name': 'fthg', 'type': 'int32'},
        {'name': 'ftag', 'type': 'int32'},
        {'name': 'odd_h', 'type': 'float'},
        {'name': 'odd_d', 'type': 'float'},
        {'name': 'odd_a', 'type': 'float'}
    ],
    'default_sorting_field': 'fthg'
}
client.collections.create(book_sachema)
# Out:
# {'created_at': 1767921226,
#  'default_sorting_field': 'fthg',
#  'enable_nested_fields': False,
#  'fields': [{'facet': False,
#    'index': True,
#    'infix': False,
#    'locale': '',
#    'name': 'id_odsp',
#    'optional': False,
#    'sort': False,
#    'stem': False,
#    'stem_dictionary': '',
#    'store': True,
#    'type': 'string'},
#   {'facet': False,
#    'index': True,
#    'infix': False,
#    'locale': '',
#    'name': 'link_odsp',
#    'optional': False,
#    'sort': False,
#    'stem': False,
#    'stem_dictionary': '',
#    'store': True,
#    'type': 'string'},
#   {'facet': True,
#    'index': True,
#    'infix': False,
#    'locale': '',
#    'name': 'adv_stats',
#    'optional': False,
#    'sort': True,
#    'stem': False,
#    'stem_dictionary': '',
#    'store': True,
#    'type': 'bool'},
#   {'facet': False,
#    'index': True,
#    'infix': False,
#    'locale': '',
#    'name': 'date',
#    'optional': False,
#    'sort': False,
#    'stem': False,
# ...

# %%
# uploading document. interupted to input partially (~3000 records)
for doc in data_dict:
    json_doc = json.dumps(doc)
    client.collections['football_articles'].documents.import_(json_doc)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 3
#       1 for doc in data_dict:
#       2     json_doc = json.dumps(doc)
# ----> 3     client.collections['football_articles'].documents.import_(json_doc)
#
# File c:\Users\ronee\Desktop\Project\practice\RAG\.venv\Lib\site-packages\typesense\documents.py:315, in Documents.import_(self, documents, import_parameters, batch_size)
#     297 """
#     298 Import documents into the collection.
#     299
#    (...)    312     TypesenseClientError: If an empty list of documents is provided.
#     313 """
#     314 if isinstance(documents, (str, bytes)):
# --> 315     return self._import_raw(documents, import_parameters)
#     317 if batch_size:
#     318     return self._batch_import(documents, import_parameters, batch_size)
#
# ...
